# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mpg.csv')

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p  \
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# ## 반복문을 이용해서 시각화 그래프 그리기

# %%
import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2) # 4가지 그래프
plt.figure(figsize=(16,10))
plt.subplots_adjust(wspace= 0.5, hspace=0.4) # 그래프가 여러 개 그려질 경우 충돌 방지

mpg_features = ['manufacturer','model','category','drv'] # 범주형 데이터만 가지고 그래프 그리기 문자열 데이터들
# sns countplot 그리기!
for idx, feature in enumerate(mpg_features):
    ax = plt.subplot(grid[idx])
    #sns 카운트플롯 파라미터들
    sns.countplot(x = feature,
                 data= df,
                 hue = 'drv',
                 palette = 'pastel',
                 ax =ax)
    plt.xticks(rotation=90) #x축의 값을 축전환하는 코드
    ax.set_title(f'{feature} Distribution')

# %%
import pandas as pd
import seaborn as sns
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Seaborn 시각화 그래프

# %% [markdown]
# ### sns.histplot

# %%
sns.histplot(df['age'],bins = 20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['age'],bins = 20, kde =True) #연속확률분포 그래프 그리기 kde 인자로
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#count를 통한 그래프 
sns.countplot(x='pclass', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
#count를 x축과 y축을 지정
#barplot
sns.barplot(x='pclass', y='survived',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %% [markdown]
# - y축은 평균을 중심으로 계산한다.

# %%
#count를 x축과 y축을 지정
#barplot
sns.barplot(x='pclass', y='sex',data=df)
# y축이 범주형 변수로 들어가게 되면 반전 되면서 아래 그래프처럼 보이게 된다.
# Out:
# <Axes: xlabel='pclass', ylabel='sex'>

# %% [markdown]
# - barplot estimator 조정할 수 있다. 평균이지만, 합계 등으로 바꿀 수 있다.

# %%
#count를 x축과 y축을 지정
#barplot
sns.barplot(x='pclass', y='sex',data=df, estimator= sum)
# y축이 범주형 변수로 들어가게 되면 반전 되면서 아래 그래프처럼 보이게 됨
# Out:
# <Axes: xlabel='pclass', ylabel='sex'>

# %% [markdown]
# - hue 인자를 넣으면 범례를 추가

# %%
sns.barplot(x ='pclass',y='age',hue='sex', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.barplot(x ='pclass',y='survived',hue='sex', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='survived'>

# %%
sns.boxplot(y='age',data=df)
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(x='pclass',y='age',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x='pclass',y='age',hue = 'survived',data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
# 안좋은 예시
sns.boxplot(x='age',y='pclass',hue = 'survived',data=df)
# Out:
# <Axes: xlabel='age', ylabel='pclass'>

# %% [markdown]
# - 바이올린차트
# - 연속 확률 분포 차트 곡선이랑 박스플롯 함께 시각화
# - 연속확률분포 곡선 대칭으로 그리고, 가운데 박스플롯 몸통 수염 나타내는 그래프

# %%
sns.violinplot(x='pclass',y='age',data= df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.violinplot(x='pclass',y='age',hue= 'survived',data= df)
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %% [markdown]
# - 다양한 시각화도 반복문으로 편하게 할 수 있다
#
# - countplot 수를 세는 것 y축 고정이 되어 있다.
# - barplot 자유롭게 y축과 estimator 조절할 수 있다

# %%
tt_columns = ['survived','pclass','sex']

fig, axs = plt.subplots(nrows =1, ncols = len(tt_columns), figsize=(15,3))

for idx, columns in enumerate(tt_columns):
    print('idx',idx)
    sns.countplot(x=columns, data=df, ax=axs[idx])
# Out:
# idx 0
# idx 1
# idx 2

# %%
tt_columns = ['embarked','pclass','sex']

fig, axs = plt.subplots(nrows =1, ncols = len(tt_columns), figsize=(15,3))

for idx, columns in enumerate(tt_columns):
    print('idx',idx)
    sns.barplot(x=columns, y='survived',data=df, ax=axs[idx],estimator= sum)
# Out:
# idx 0
# idx 1
# idx 2

# %% [markdown]
# ## 시계열 데이터
# - 시간의 흐름을 보여주는 인덱스, datetime 이용해 시계열 데이터를 확인할 수 있다.
# - 기존 분석과는 다름
# - 보간법에서 본 것처럼, 시간의 흐름에 따라 데이터가 특성이 생성되는 것 이 시간의 흐름을 마음대로 바꾸게 되면 -> 시간의 특성이 사라지게 되는 것
# - 예측을 진행할 때 문제가 될 수 있다.
#
# - ML에서 train_test_split
# - 시계열은 랜덤하게 나눌 수가 없다.
# - 시계열 데이터는 time과 관련한 나눠서 데이터를 분할한다.
#
# ## 시계열 데이터는
# - pandas 에서 제공하는 datetime, TimeStamp, Timedelta 등 여러가지 제공하고 있다.
# - datetime 시계열 데이터로 변환하여 많이 사용하고 있다.
#
# - datetime
# - date + time 개념으로
# - date 연, 월, 일 이루어지고, time 시간, 분, 초 , 마이크로초 등으로 이루어짐
# - Timestamp : 날짜와 시간을 모두 가지고 있고 단일객체
# - Timedelta : 객체를 가지고 있으면서 시간의 계산이 가능하다 ( 덧셈, 뺄셈 가능 )
#
# ## 시계열 분석
# - 고전적인 시계열 분석 (AR, MA, ARIMA ,SARIMA 등등 )
# - 보간법으로 바로 진행하는 것들
# - facebook에서 제공하는 prohpet 쉽게 사용할 수 있다.
# - tensorflow 제공하는 시계열 분석 패키지
# - DL LSTM, RNN 등등

# %%
import pandas as pd 
import datetime

# %%
#datetime으로 시계열 데이터 만들기

date = datetime.date(year=2023, month=11, day=26)
time = datetime.time(hour= 23, minute=29, second= 5, microsecond= 1234)

# %%
date
# Out:
# datetime.date(2023, 11, 26)

# %%
time
# Out:
# datetime.time(23, 29, 5, 1234)

# %%
dt = datetime.datetime(year=2023, month=11, day=26,hour= 23, minute=29, second= 5, microsecond= 1234)

# %%
dt
# Out:
# datetime.datetime(2023, 11, 26, 23, 29, 5, 1234)

# %%
# timedelta
td = datetime.timedelta(days=31)

# %%
td
# Out:
# datetime.timedelta(days=31)

# %%
#날짜를 계산해야 하는 경우 쉽게 사용할 수 있다.
print(date + td)
# Out:
# 2023-12-27

# %%
print(dt+td)
# Out:
# 2023-12-27 23:29:05.001234

# %% [markdown]
# ### datetime  판다스에서 제공하는 메서드(method)
#
# - 날짜를 pd.to_datetime(날짜)

# %%
pd.to_datetime('2023-11-26')
# Out:
# Timestamp('2023-11-26 00:00:00')

# %% [markdown]
# - pd.to_datetime
# - 인간의 다양한 날짜 표기법을 자동으로 시계열 데이터로 인식
#
# - 26-11-2023
# - 2023/11/26
# - 2023.11.26
# - 날짜를 적는 방법이 다양
#
# - 날짜로 인식할 수 없는 이상한 숫자는 자동으로 확인 가능

# %%
# pd.to_datetime의 좋은 예시

eg_dt = pd.Series(['2023-11-26','2023/11/26','2023.11.26','26-11-2023','26/11/2023','2023-13-26','2023-11-32'])

# %%
pd.to_datetime(eg_dt,dayfirst=True ,errors='coerce') #에러를 na값으로!
# Out:
# /var/folders/sz/167qwb595mqgwry5mm8685n00000gn/T/ipykernel_27480/3299308423.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   pd.to_datetime(eg_dt,dayfirst=True ,errors='coerce') #에러를 na값으로!
# 0   2023-11-26
# 1          NaT
# 2          NaT
# 3          NaT
# 4          NaT
# 5          NaT
# 6          NaT
# dtype: datetime64[ns]

# %% [markdown]
# ### 실제 데이터를 가지고 시계열 데이터로 만들기

# %%
df =pd.read_csv('crime.csv')

# %%
df
# Out:
#         Unnamed: 0               OFFENSE_TYPE_ID OFFENSE_CATEGORY_ID
# 0                0     traffic-accident-dui-duid    traffic-accident  \
# 1                1    vehicular-eluding-no-chase    all-other-crimes
# 2                2          disturbing-the-peace     public-disorder
# 3                3                        curfew     public-disorder
# 4                4            aggravated-assault  aggravated-assault
# ...            ...                           ...                 ...
# 460906      460906    burglary-business-by-force            burglary
# 460907      460907  weapon-unlawful-discharge-of    all-other-crimes
# 460908      460908        traf-habitual-offender    all-other-crimes
# 460909      460909       criminal-mischief-other     public-disorder
# 460910      460910                   theft-other             larceny
#
#               REPORTED_DATE     GEO_LON    GEO_LAT            NEIGHBORHOOD_ID
# ...

# %% [markdown]
# ### 시계열 데이터를 다룰 때
# - 가장 먼저 시계열 데이터를 -> 시계열 데이터 타입으로 만들어야 함

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460911 entries, 0 to 460910
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           460911 non-null  int64
#  1   OFFENSE_TYPE_ID      460911 non-null  object
#  2   OFFENSE_CATEGORY_ID  460911 non-null  object
#  3   REPORTED_DATE        460911 non-null  object
#  4   GEO_LON              457296 non-null  float64
#  5   GEO_LAT              457296 non-null  float64
#  6   NEIGHBORHOOD_ID      460911 non-null  object
#  7   IS_CRIME             460911 non-null  int64
#  8   IS_TRAFFIC           460911 non-null  int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 31.6+ MB

# %% [markdown]
# - REPORTED_DATE 문자열로 인식하고 있다.
# - 시계열로 바꿔야 한다.

# %%
#datetime으로 꼭 변환하기!!
df['REPORTED_DATE']= pd.to_datetime(df['REPORTED_DATE'])

# %%
#꼭 datetime으로 시계열 데이터 만들기
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460911 entries, 0 to 460910
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           460911 non-null  int64
#  1   OFFENSE_TYPE_ID      460911 non-null  object
#  2   OFFENSE_CATEGORY_ID  460911 non-null  object
#  3   REPORTED_DATE        460911 non-null  datetime64[ns]
#  4   GEO_LON              457296 non-null  float64
#  5   GEO_LAT              457296 non-null  float64
#  6   NEIGHBORHOOD_ID      460911 non-null  object
#  7   IS_CRIME             460911 non-null  int64
#  8   IS_TRAFFIC           460911 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 31.6+ MB

# %% [markdown]
# ### 시계열 데이터 쉽게 가공하기 위해서는
# - index 지정하기!

# %%
df=df.set_index('REPORTED_DATE')
# 인덱스로 만들기

# %%
df
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID
# REPORTED_DATE
# 2014-06-29 02:01:00           0     traffic-accident-dui-duid  \
# 2014-06-29 01:54:00           1    vehicular-eluding-no-chase
# 2014-06-29 02:00:00           2          disturbing-the-peace
# 2014-06-29 02:18:00           3                        curfew
# 2014-06-29 04:17:00           4            aggravated-assault
# ...                         ...                           ...
# 2017-09-13 05:48:00      460906    burglary-business-by-force
# 2017-09-12 20:37:00      460907  weapon-unlawful-discharge-of
# 2017-09-12 16:32:00      460908        traf-habitual-offender
# 2017-09-12 13:04:00      460909       criminal-mischief-other
# 2017-09-12 09:30:00      460910                   theft-other
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2014-06-29 02:01:00    traffic-accident -105.000149  39.745753  \
# ...

# %% [markdown]
# ### 자유롭게 시계열을 가지고 놀 수 있따!

# %%
# 내가 원하는 날짜를 다 뽑을 수 있다!
df.loc['2017']
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID
# REPORTED_DATE
# 2017-05-22 14:41:00        7261              traffic-accident  \
# 2017-05-17 20:35:00        7262             threats-to-injure
# 2017-06-07 07:47:00        7265   burglary-residence-by-force
# 2017-05-26 16:46:00        7270                   theft-other
# 2017-06-07 07:42:00        7272          criminal-trespassing
# ...                         ...                           ...
# 2017-09-13 05:48:00      460906    burglary-business-by-force
# 2017-09-12 20:37:00      460907  weapon-unlawful-discharge-of
# 2017-09-12 16:32:00      460908        traf-habitual-offender
# 2017-09-12 13:04:00      460909       criminal-mischief-other
# 2017-09-12 09:30:00      460910                   theft-other
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2017-05-22 14:41:00    traffic-accident -104.673812  39.849292  \
# ...

# %%
df.loc['2016-09']
# Out:
#                      Unnamed: 0            OFFENSE_TYPE_ID
# REPORTED_DATE
# 2016-09-13 10:58:00       22153                 assault-dv  \
# 2016-09-07 20:07:00       23119                 assault-dv
# 2016-09-26 08:39:00       23666        robbery-car-jacking
# 2016-09-06 10:10:00       28075    criminal-mischief-other
# 2016-09-07 02:20:00       28193                 traf-other
# ...                         ...                        ...
# 2016-09-25 10:38:00      378634  criminal-mischief-mtr-veh
# 2016-09-26 11:00:00      378635       fraud-identity-theft
# 2016-09-13 16:03:00      378760             assault-simple
# 2016-09-23 22:12:00      379034             assault-simple
# 2016-09-13 22:43:00      382819              arson-vehicle
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2016-09-13 10:58:00  other-crimes-against-persons -105.027174  39.711779  \
# 2016-09-07 20:07:00  other-crimes-against-persons -105.024461  39.663195
# ...

# %%
df.loc['2016-09-30']
# Out:
#                      Unnamed: 0              OFFENSE_TYPE_ID
# REPORTED_DATE
# 2016-09-30 11:06:00       52779            indecent-exposure  \
# 2016-09-30 13:46:00      129308         fraud-identity-theft
# 2016-09-30 09:41:00      319648             traffic-accident
# 2016-09-30 15:16:00      319649             traffic-accident
# 2016-09-30 21:04:00      319650  theft-purse-snatch-no-force
# ...                         ...                          ...
# 2016-09-30 12:46:00      352887                theft-bicycle
# 2016-09-30 20:28:00      357798               assault-simple
# 2016-09-30 06:14:00      360479                sex-aslt-rape
# 2016-09-30 11:05:00      368842            sex-aslt-rape-pot
# 2016-09-30 16:44:00      377654       menacing-felony-w-weap
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2016-09-30 11:06:00  other-crimes-against-persons -104.922294  39.758373  \
# ...

# %%
df.loc['Dec 2014']
# Out:
#                      Unnamed: 0              OFFENSE_TYPE_ID
# REPORTED_DATE
# 2014-12-19 17:42:00        1219             traffic-accident  \
# 2014-12-06 08:25:00        1225         disturbing-the-peace
# 2014-12-19 08:29:00        1301  burglary-residence-no-force
# 2014-12-01 22:13:00        1322            liquor-possession
# 2014-12-30 08:26:00        1341     theft-items-from-vehicle
# ...                         ...                          ...
# 2014-12-18 22:36:00      377801         criminal-trespassing
# 2014-12-10 19:35:00      377834               assault-simple
# 2014-12-16 13:51:00      379049               assault-simple
# 2014-12-20 08:37:00      416416     drug-methampetamine-sell
# 2014-12-16 13:06:00      427420                   harassment
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2014-12-19 17:42:00              traffic-accident -104.940355  39.781688  \
# ...

# %%
df.loc['2014'].sort_index()
# Out:
#                      Unnamed: 0            OFFENSE_TYPE_ID
# REPORTED_DATE
# 2014-01-01 00:08:00       99814                 traf-other  \
# 2014-01-01 00:08:00      214696     traf-habitual-offender
# 2014-01-01 00:38:00      224109     theft-of-motor-vehicle
# 2014-01-01 00:39:00       83972             robbery-street
# 2014-01-01 01:00:00      236308         aggravated-assault
# ...                         ...                        ...
# 2014-12-31 23:59:00      226091  weapon-carrying-concealed
# 2014-12-31 23:59:00      148309           traffic-accident
# 2014-12-31 23:59:00       97411                 assault-dv
# 2014-12-31 23:59:00      126879     theft-of-motor-vehicle
# 2014-12-31 23:59:00      226092       disturbing-the-peace
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2014-01-01 00:08:00              all-other-crimes -104.841945  39.773764  \
# 2014-01-01 00:08:00              all-other-crimes -104.841945  39.773764
# ...

# %% [markdown]
# - 시간 단위까지도 데이터 추출이 가능하고
# - 원하는 시간을 추출할 수 있다.

# %%
#시간대별로도 원하는 데이터를 추출할 수 있다.
df.between_time('13:00','16:00')
# Out:
#                      Unnamed: 0              OFFENSE_TYPE_ID
# REPORTED_DATE
# 2013-01-24 13:49:00          12              theft-from-bldg  \
# 2012-02-27 15:23:00          17                  theft-other
# 2012-08-06 15:15:00          23             traffic-accident
# 2014-03-28 14:45:00          41                   traf-other
# 2012-02-17 14:03:00          45             traffic-accident
# ...                         ...                          ...
# 2017-09-12 13:40:00      460894   burglary-business-by-force
# 2017-09-12 13:40:00      460901       theft-of-motor-vehicle
# 2017-09-12 15:33:00      460904           public-peace-other
# 2017-09-12 14:00:00      460905  forgery-poss-of-forged-inst
# 2017-09-12 13:04:00      460909      criminal-mischief-other
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2013-01-24 13:49:00             larceny -104.934536  39.731625  \
# 2012-02-27 15:23:00             larceny -104.958944  39.724311
# ...

# %% [markdown]
# - 정각 시간에도 데이터 추출 가능하다.

# %%
df.at_time('14:00')
# Out:
#                      Unnamed: 0                OFFENSE_TYPE_ID
# REPORTED_DATE
# 2013-10-31 14:00:00         760                     assault-dv  \
# 2013-03-23 14:00:00         938               drug-heroin-sell
# 2015-10-01 14:00:00        1893                    theft-other
# 2014-10-21 14:00:00        2861         theft-of-motor-vehicle
# 2015-04-30 14:00:00        3800                 assault-simple
# ...                         ...                            ...
# 2017-09-21 14:00:00      459978      public-order-crimes-other
# 2017-09-20 14:00:00      460000       fraud-by-use-of-computer
# 2017-09-11 14:00:00      460126                    theft-other
# 2017-08-26 14:00:00      460518  burg-auto-theft-resd-no-force
# 2017-09-12 14:00:00      460905    forgery-poss-of-forged-inst
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2013-10-31 14:00:00  other-crimes-against-persons -105.004212  39.696100  \
# ...

# %% [markdown]
# ### 시계열 문법 중
# - offsets, first 등 날짜 중에 근로기준날만 뽑을 수 있고, 첫주 월요일 뽑을 수 있고 다양하게 문법을 사용할 수 있다.
#
# - offsets
# - first
# - 두 가지 문법을 이용하면 구글링하면 원하는 특정 기준의 날짜들을 다 추출할 수 있다.

# %% [markdown]
# ### resample 함수
# - 간단하게 요약해 주는 함수!

# %%
df
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID
# REPORTED_DATE
# 2014-06-29 02:01:00           0     traffic-accident-dui-duid  \
# 2014-06-29 01:54:00           1    vehicular-eluding-no-chase
# 2014-06-29 02:00:00           2          disturbing-the-peace
# 2014-06-29 02:18:00           3                        curfew
# 2014-06-29 04:17:00           4            aggravated-assault
# ...                         ...                           ...
# 2017-09-13 05:48:00      460906    burglary-business-by-force
# 2017-09-12 20:37:00      460907  weapon-unlawful-discharge-of
# 2017-09-12 16:32:00      460908        traf-habitual-offender
# 2017-09-12 13:04:00      460909       criminal-mischief-other
# 2017-09-12 09:30:00      460910                   theft-other
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT
# REPORTED_DATE
# 2014-06-29 02:01:00    traffic-accident -105.000149  39.745753  \
# ...

# %% [markdown]
# - 해당 범죄나, 교통사고건에 대해서 월별로 카운팅을 하고 싶다? 연도별로 등등 group by의 개념

# %%
df.resample('Y').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df.resample('Y').sum()
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/resample.py:888, in Resampler.sum(self, numeric_only, min_count, *args, **kwargs)
#     886 maybe_warn_args_and_kwargs(type(self), "sum", args, kwargs)
#     887 nv.validate_resampler_func("sum", args, kwargs)
# --> 888 return self._downsample("sum", numeric_only=numeric_only, min_count=min_count)
#
# File /opt/anaconda3/envs/bda/lib/python3.8/site-packages/pandas/core/resample.py:1297, in DatetimeIndexResampler._downsample(self, how, **kwargs)
#    1293     return self.asfreq()
#    1295 # we are downsampling
#    1296 # we want to call the actual grouper method here
# -> 1297 result = obj.groupby(self.grouper, axis=self.axis).aggregate(how, **kwargs)
#    1299 return self._wrap_result(result)
#
# ...

# %%
df_crime=df[['IS_CRIME']]

# %%
df_crime.resample('Y').sum() # 연도별로 해당 사건에 대한 전체 합을 계산 가능
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-12-31        37286
# 2013-12-31        50698
# 2014-12-31        62690
# 2015-12-31        65894
# 2016-12-31        67381
# 2017-12-31        51902

# %%
df[['IS_CRIME']].resample('Y').sum()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-12-31        37286
# 2013-12-31        50698
# 2014-12-31        62690
# 2015-12-31        65894
# 2016-12-31        67381
# 2017-12-31        51902

# %%
df[['IS_CRIME']].resample('M').sum()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-01-31         2660
# 2012-02-29         2353
# 2012-03-31         2869
# 2012-04-30         3070
# 2012-05-31         3321
# ...                 ...
# 2017-05-31         5965
# 2017-06-30         5972
# 2017-07-31         6005
# 2017-08-31         6568
# 2017-09-30         5417
#
# [69 rows x 1 columns]

# %%
df[['IS_CRIME']].resample('W').sum()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-01-08          551
# 2012-01-15          600
# 2012-01-22          654
# 2012-01-29          655
# 2012-02-05          536
# ...                 ...
# 2017-09-03         1458
# 2017-09-10         1309
# 2017-09-17         1474
# 2017-09-24         1332
# 2017-10-01          753
#
# [300 rows x 1 columns]

# %%
df[['IS_CRIME']].resample('D').sum()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-01-02           34
# 2012-01-03           64
# 2012-01-04           89
# 2012-01-05           94
# 2012-01-06           96
# ...                 ...
# 2017-09-25          166
# 2017-09-26          192
# 2017-09-27          200
# 2017-09-28          169
# 2017-09-29           26
#
# [2098 rows x 1 columns]

# %%
df[['IS_CRIME']].resample('D').mean()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-01-02     0.548387
# 2012-01-03     0.598131
# 2012-01-04     0.597315
# 2012-01-05     0.652778
# 2012-01-06     0.671329
# ...                 ...
# 2017-09-25     0.674797
# 2017-09-26     0.735632
# 2017-09-27     0.738007
# 2017-09-28     0.667984
# 2017-09-29     0.928571
#
# [2098 rows x 1 columns]

# %%
df[['IS_CRIME']].resample('D').std()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2012-01-02     0.501716
# 2012-01-03     0.492583
# 2012-01-04     0.492092
# 2012-01-05     0.477749
# 2012-01-06     0.471381
# ...                 ...
# 2017-09-25     0.469406
# 2017-09-26     0.441843
# 2017-09-27     0.440532
# 2017-09-28     0.471870
# 2017-09-29     0.262265
#
# [2098 rows x 1 columns]
