# %% [markdown]
# ### 데이터분석 기초반
# - 데이터프레임을 사용하기 위한 pandas
# - 데이터프레임에서 연산 등을 쉽고 빠르게 하기 위한 numpy
# - 모델링 등 ML 쪽에 많이 사용하는 sklearn을 사용

# %%
import pandas as pd

# %% [markdown]
# - 2차원 리스트

# %%
a= [1,2,3,4,5]

# %%
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(len(a)):
    print(a[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
b=[[1,2],[3,4]]

# %%
b #데이터프레임과 가장 유사한 개념
# Out:
# [[1, 2], [3, 4]]

# %% [markdown]
# - 1차원과 다르게 2차원에서는 가로 세로 x축과 y축으로 행렬 구조
# - 행렬 (행과 열의 구조)

# %%
print(b[0][0])
print(b[0][1])
print(b[1][0])
print(b[1][1])
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
#     -       0열     1열
# - 행(index) 1(0,0), 2(0,1)
# - 행(index) 3(1,0), 4(1,1)

# %% [markdown]
# ### 데이터프레임을 이해하면

# %%
df=pd.read_csv('mpg.csv')

# %%
df# 행렬의 개념으로 이해
df# 왼쪽에 있는 수치는 인덱스
df# 상단에 있는 manufacturer,... category 컬럼
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p  \
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# - 데이터의 형식의 구조 이해가 중요

# %%
#리스트
a= [1,2,3,4,5]

# %%
a # 시퀀스 객체는 인덱스 부여
a[0]
# Out:
# 1

# %% [markdown]
# ### 데이터프레임을 접근시
# - 행과, 열을 기준으로 접근

# %% [markdown]
# - 데이터프레임 생성

# %%
bda=pd.DataFrame({'데분기':[310,100,200,300],
             '파문기':[200,100,500,400],
             'SQL':[100,200,300,400]})

# %%
bda
# Out:
#    데분기  파문기  SQL
# 0  310  200  100
# 1  100  100  200
# 2  200  500  300
# 3  300  400  400

# %% [markdown]
# - 컬럼(column)을 기준으로 데이터를 추출
# - 컬럼을 기준으로 추출시 [] 대괄호를 이용하여 추출

# %%
bda['데분기']
# Out:
# 0    310
# 1    100
# 2    200
# 3    300
# Name: 데분기, dtype: int64

# %%
bda[['데분기','파문기']]
# Out:
#    데분기  파문기
# 0  310  200
# 1  100  100
# 2  200  500
# 3  300  400

# %% [markdown]
# - pandas에서 제공하는 데이터 구조가 2개 (데이터프레임, 시리즈)
# - 2차원이상으로 이뤄진 것
# - 시리즈는 하나의 차원 -> 브로드캐스팅이 되어서 다양하게 연산 가능

# %% [markdown]
# - mpg 데이터로 연습

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
tt=sns.load_dataset('titanic')

# %%
tt[['survived','fare']]
# Out:
#      survived     fare
# 0           0   7.2500
# 1           1  71.2833
# 2           1   7.9250
# 3           1  53.1000
# 4           0   8.0500
# ..        ...      ...
# 886         0  13.0000
# 887         1  30.0000
# 888         0  23.4500
# 889         1  30.0000
# 890         0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# - 열은 [] 대괄호로 가지고 오는 것
# - 행은 index 접근
# - index range 슬라이싱

# %%
tt[:] #전체
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tt[:100:2]
# Out:
#     survived  pclass     sex    age  sibsp  parch      fare embarked   class
# 0          0       3    male  22.00      1      0    7.2500        S   Third  \
# 2          1       3  female  26.00      0      0    7.9250        S   Third
# 4          0       3    male  35.00      0      0    8.0500        S   Third
# 6          0       1    male  54.00      0      0   51.8625        S   First
# 8          1       3  female  27.00      0      2   11.1333        S   Third
# 10         1       3  female   4.00      1      1   16.7000        S   Third
# 12         0       3    male  20.00      0      0    8.0500        S   Third
# 14         0       3  female  14.00      0      0    7.8542        S   Third
# 16         0       3    male   2.00      4      1   29.1250        Q   Third
# 18         0       3  female  31.00      1      0   18.0000        S   Third
# 20         0       2    male  35.00      0      0   26.0000        S  Second
# ...

# %% [markdown]
# - loc (인덱스 기준으로 데이터를 추출)
# - iloc 함수 (데이터프레임 순서에 따라 추출)

# %%
tt.loc[10:100]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 10          1       3  female   4.0      1      1  16.7000        S   Third  \
# 11          1       1  female  58.0      0      0  26.5500        S   First
# 12          0       3    male  20.0      0      0   8.0500        S   Third
# 13          0       3    male  39.0      1      5  31.2750        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 96          0       1    male  71.0      0      0  34.6542        C   First
# 97          1       1    male  23.0      0      1  63.3583        C   First
# 98          1       2  female  34.0      0      1  23.0000        S  Second
# 99          0       2    male  34.0      1      0  26.0000        S  Second
# 100         0       3  female  28.0      0      0   7.8958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# - fare 요금데이터와 pclass 데이터를 분리

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
tt['pclass_new'] = tt['fare']/tt['pclass']

# %%
tt.describe() #요약통계를 추출
# 요약통계는 연속형 데이터가 가능
# 범주형이나, 문자열데이터는 요약통계를 만들 수 없음
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000  \
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#
#        pclass_new
# count  891.000000
# mean    25.046650
# std     51.245594
# min      0.000000
# 25%      2.641667
# 50%      6.325000
# 75%     23.183333
# max    512.329200

# %%
tt.describe(include='all') #요약통계를 추출
# Out:
#           survived      pclass   sex         age       sibsp       parch
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000  \
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive
# ...

# %%
tt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# - 전체 로우데이터를 -> 원하는 요구 조건 -> 원하는 요구조건-> 내가 원하는 데이터 생성
# - 메서드체이닝 . 찍어서 이어지는 것처럼 pandas도 동일하게 접근

# %%
tt.fare.sum()
# Out:
# 28693.9493
